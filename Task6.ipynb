# %% [markdown]
# # By:Priyanshi Garg
#
# ## THE SPARKS FOUNDATION
#
# ## DATA SCIENCE AND BUSINESS ANALYTICS INTERN (#GRIPJan21)
#
# ### Task 6 :Prediction using Decision Tree Algorithm
#
# #### Create the Decision Tree classifier and visualize it graphically.The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# #### Dataset:https://bit.ly/3kXTdox

# %% [markdown]
# ###### Importing the libraries and dataset

# %%
# Importing libraries in Python
import graphviz
import sklearn.datasets as datasets
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydot


# Loading the iris dataset
iris=datasets.load_iris()
x=iris.data
y=iris.target


# Forming the iris dataframe

data=pd.DataFrame(iris.data, columns=iris.feature_names)
data['species']=iris['target']
data['species']=data['species'].apply(lambda x:iris['target_names'][x])
data.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# #### Visualizing the data

# %%
sns.FacetGrid(data,hue='species',height=5,aspect=1).map(plt.scatter,'sepal length (cm)','sepal width (cm)').add_legend()
plt.show()
sns.FacetGrid(data,hue='species',height=5, aspect=1).map(plt.scatter,'petal length (cm)','petal width (cm)').add_legend()
plt.show()

# %% [markdown]
# #### Decision Tree Model Training

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.1,random_state=1)
dtree=DecisionTreeClassifier()
dtree.fit(X_train,Y_train)
print("Training Complete")
Y_pred=dtree.predict(X_test)
# Out:
# Training Complete

# %% [markdown]
# #### Comparing Actual Vs Predicted Values

# %%
d=pd.DataFrame({'Actual':Y_test,'Predicted':Y_pred})
d
# Out:
#     Actual  Predicted
# 0        0          0
# 1        1          1
# 2        1          1
# 3        0          0
# 4        2          2
# 5        1          1
# 6        2          2
# 7        0          0
# 8        0          0
# 9        2          2
# 10       1          1
# 11       0          0
# 12       2          2
# 13       1          1
# 14       1          1

# %% [markdown]
# #### Creating the Decision tree Visualization

# %%
# Import necessary libraries for graph viz
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=iris.feature_names,class_names=iris.target_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# #### Now you can predict the iris class for any data by entering it through the Decision Tree Model

# %%
classname=['Setosa','Versicolor','Virginica']
sl=float(input("Enter sepal Length"))
sw=float(input("Enter sepal Width"))
pl=float(input("Enter petal Length"))
pw=float(input("Enter petal width"))
irisclass=dtree.predict([[sl,sw,pl,pw]])
print("\n ")
print("Iris Class="+classname[irisclass[0]])
# Out:
# Enter sepal Length4.6
# Enter sepal Width3.1
# Enter petal Length1.5
# Enter petal width0.2
#
#
# Iris Class=Setosa

# %% [markdown]
# ### Conclusion
# #### I was able to carry-out Prediction using Decision Tree classifier and was able to predict the right classes on new data accordingly.
# ### Thankyou
